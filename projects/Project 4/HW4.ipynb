# %% [markdown]
# _todo: replicate the table on slide 19 of the session 4 slides. This involves calculating pearson correlations, standardized regression coefficients, "usefulness", Shapley values for a linear regression, Johnson's relative weights, and the mean decrease in the gini coefficient from a random forest. You may use packages built into R or Python._
#
# _If you want a challenge, either (1) implement one or more of the measures yourself. "Usefulness" is rather easy to program up. Shapley values for linear regression are a bit more work. Or (2) add additional measures to the table such as the importance scores from XGBoost._

# %%
import pandas as pd
import numpy as np
import pyrsm as rsm 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from scipy.stats import pearsonr
import shap
from sklearn.inspection import permutation_importance
from xgboost import XGBRegressor

data = pd.read_csv('/home/jovyan/Desktop/MGTA495-2/projects/Project 4/data_for_drivers_analysis.csv')

# %%
data.head()
# Out:
# <bound method NDFrame.head of       brand     id  satisfaction  trust  build  differs  easy  appealing  \
# 0         1     98             3      1      0        1     1          1
# 1         1    179             5      0      0        0     0          0
# 2         1    197             3      1      0        0     1          1
# 3         1    317             1      0      0        0     0          1
# 4         1    356             4      1      1        1     1          1
# ...     ...    ...           ...    ...    ...      ...   ...        ...
# 2548     10  17800             5      1      1        0     1          0
# 2549     10  17808             3      1      0        0     1          0
# 2550     10  17893             5      0      1        1     0          0
# 2551     10  17984             3      1      1        0     1          0
# 2552     10  18073             4      0      1        0     1          0
#
#       rewarding  popular  service  impact
# 0             0        0        1       0
# 1             0        0        0       0
# 2             1        0        1       1
# 3             0        1        1       1
# 4             1        1        1       1
# ...         ...      ...      ...     ...
# 2548          1        1        1       1
# 2549          1        1        1       0
# 2550          0        0        0       0
# 2551          1        0        0       0
# 2552          0        0        0       0
#
# [2553 rows x 12 columns]>

# %%
# Define the independent variables (perceptions) and the dependent variable (satisfaction)
X = data[['trust', 'build', 'differs', 'easy', 'appealing', 'rewarding', 'popular', 'service', 'impact']]
y = data['satisfaction']

# Standardize the independent variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Fit a linear regression model
reg = LinearRegression().fit(X_scaled, y)

# Standardized regression coefficients
standardized_coefficients = reg.coef_

# Calculate permutation importance (as an approximation for Shapley values)
perm_importance = permutation_importance(reg, X_scaled, y, n_repeats=30, random_state=42)
perm_importance_mean = perm_importance.importances_mean

# Fit a Random Forest model for Mean Decrease in Gini Coefficient
rf = RandomForestRegressor()
rf.fit(X_scaled, y)
gini_importance = rf.feature_importances_

# Fit an XGBoost model and get feature importance
xgb_model = XGBRegressor()
xgb_model.fit(X_scaled, y)
xgb_importance = xgb_model.feature_importances_

# Calculate Johnson's Relative Weights (using a suitable approximation)
johnson_weights = np.abs(standardized_coefficients) / np.sum(np.abs(standardized_coefficients))

# Calculate Pearson Correlations
pearson_correlations = {col: pearsonr(X[col], y)[0] for col in X.columns}

# Calculate "Usefulness" as an average of standardized coefficients, Shapley values, and Johnson's epsilon
usefulness = (np.abs(standardized_coefficients) + perm_importance_mean + johnson_weights) / 3

# Create the table
results = pd.DataFrame({
    'Perception': [
        'Is offered by a brand I trust', 'Helps build credit quickly', 'Is different from other cards',
        'Is easy to use', 'Has appealing benefits or rewards', 'Rewards me for responsible usage',
        'Is used by a lot of people', 'Provides outstanding customer service', 'Makes a difference in my life'
    ],
    'Pearson Correlations (%)': [round(pearson_correlations[col] * 100, 1) for col in X.columns],
    'Standardized Multiple Regression Coefficients (%)': [round(coef * 100, 1) for coef in standardized_coefficients],
    'Shapley Values (%)': [round(value * 100, 1) for value in perm_importance_mean],
    'Johnson\'s Epsilon (%)': [round(weight * 100, 1) for weight in johnson_weights],
    'Mean Decrease in RF Gini Coefficient (%)': [round(value * 100, 1) for value in gini_importance],
    'XGBoost Importance (%)': [round(value * 100, 1) for value in xgb_importance],
    'Usefulness (%)': [round(value * 100, 1) for value in usefulness]
})

# Display the final results
results = results[['Perception', 'Pearson Correlations (%)', 'Standardized Multiple Regression Coefficients (%)',
                   'Shapley Values (%)', 'Johnson\'s Epsilon (%)', 'Mean Decrease in RF Gini Coefficient (%)',
                   'XGBoost Importance (%)', 'Usefulness (%)']]
results.index = results.index + 1

styled_df = results.style.background_gradient(cmap='Greens', axis=None, vmin=0, vmax=29)
def format_func(val):
    if isinstance(val, (int, float)):
        return f"{val:.1f}"
    return val

styled_df = styled_df.format(format_func)


styled_df
# Out:
# <style type="text/css">
# #T_11a42_row0_col1, #T_11a42_row8_col1 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_11a42_row0_col2, #T_11a42_row7_col5, #T_11a42_row8_col5 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_11a42_row0_col3 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_11a42_row0_col4 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_11a42_row0_col5 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_11a42_row0_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_11a42_row0_col7 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_11a42_row1_col1 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_11a42_row1_col2, #T_11a42_row1_col7 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_11a42_row1_col3, #T_11a42_row3_col3, #T_11a42_row5_col3, #T_11a42_row6_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_11a42_row1_col4 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_11a42_row1_col5, #T_11a42_row3_col5, #T_11a42_row5_col5 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_11a42_row1_col6 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_11a42_row2_col1, #T_11a42_row8_col6 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_11a42_row2_col2 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_11a42_row2_col3, #T_11a42_row4_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_11a42_row2_col4 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_11a42_row2_col5 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_11a42_row2_col6 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_11a42_row2_col7 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_11a42_row3_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_11a42_row3_col2, #T_11a42_row3_col7 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_11a42_row3_col4 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_11a42_row3_col6 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_11a42_row4_col1 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_11a42_row4_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_11a42_row4_col4 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_11a42_row4_col5 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_11a42_row4_col6 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_11a42_row4_col7 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_11a42_row5_col1 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_11a42_row5_col2, #T_11a42_row5_col7 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_11a42_row5_col4 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_11a42_row5_col6 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_11a42_row6_col1 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_11a42_row6_col2, #T_11a42_row6_col7 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_11a42_row6_col4 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_11a42_row6_col5 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_11a42_row6_col6 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_11a42_row7_col1 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_11a42_row7_col2, #T_11a42_row7_col7 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_11a42_row7_col3 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_11a42_row7_col4 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_11a42_row7_col6 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_11a42_row8_col2 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_11a42_row8_col3 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_11a42_row8_col4 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_11a42_row8_col7 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_11a42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11a42_level0_col0" class="col_heading level0 col0" >Perception</th>
#       <th id="T_11a42_level0_col1" class="col_heading level0 col1" >Pearson Correlations (%)</th>
#       <th id="T_11a42_level0_col2" class="col_heading level0 col2" >Standardized Multiple Regression Coefficients (%)</th>
#       <th id="T_11a42_level0_col3" class="col_heading level0 col3" >Shapley Values (%)</th>
#       <th id="T_11a42_level0_col4" class="col_heading level0 col4" >Johnson's Epsilon (%)</th>
#       <th id="T_11a42_level0_col5" class="col_heading level0 col5" >Mean Decrease in RF Gini Coefficient (%)</th>
#       <th id="T_11a42_level0_col6" class="col_heading level0 col6" >XGBoost Importance (%)</th>
#       <th id="T_11a42_level0_col7" class="col_heading level0 col7" >Usefulness (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11a42_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_11a42_row0_col0" class="data row0 col0" >Is offered by a brand I trust</td>
#       <td id="T_11a42_row0_col1" class="data row0 col1" >25.6</td>
#       <td id="T_11a42_row0_col2" class="data row0 col2" >13.6</td>
#       <td id="T_11a42_row0_col3" class="data row0 col3" >2.7</td>
#       <td id="T_11a42_row0_col4" class="data row0 col4" >25.3</td>
#       <td id="T_11a42_row0_col5" class="data row0 col5" >15.1</td>
#       <td id="T_11a42_row0_col6" class="data row0 col6" >29.0</td>
#       <td id="T_11a42_row0_col7" class="data row0 col7" >13.8</td>
#     </tr>
#     <tr>
#       <th id="T_11a42_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_11a42_row1_col0" class="data row1 col0" >Helps build credit quickly</td>
#       <td id="T_11a42_row1_col1" class="data row1 col1" >19.2</td>
#       <td id="T_11a42_row1_col2" class="data row1 col2" >2.3</td>
#       <td id="T_11a42_row1_col3" class="data row1 col3" >0.1</td>
#       <td id="T_11a42_row1_col4" class="data row1 col4" >4.4</td>
#       <td id="T_11a42_row1_col5" class="data row1 col5" >10.2</td>
#       <td id="T_11a42_row1_col6" class="data row1 col6" >7.9</td>
#       <td id="T_11a42_row1_col7" class="data row1 col7" >2.3</td>
#     </tr>
#     <tr>
#       <th id="T_11a42_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_11a42_row2_col0" class="data row2 col0" >Is different from other cards</td>
#       <td id="T_11a42_row2_col1" class="data row2 col1" >18.5</td>
#       <td id="T_11a42_row2_col2" class="data row2 col2" >3.3</td>
#       <td id="T_11a42_row2_col3" class="data row2 col3" >0.2</td>
#       <td id="T_11a42_row2_col4" class="data row2 col4" >6.1</td>
#       <td id="T_11a42_row2_col5" class="data row2 col5" >8.9</td>
#       <td id="T_11a42_row2_col6" class="data row2 col6" >5.6</td>
#       <td id="T_11a42_row2_col7" class="data row2 col7" >3.2</td>
#     </tr>
#     <tr>
#       <th id="T_11a42_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_11a42_row3_col0" class="data row3 col0" >Is easy to use</td>
#       <td id="T_11a42_row3_col1" class="data row3 col1" >21.3</td>
#       <td id="T_11a42_row3_col2" class="data row3 col2" >2.6</td>
#       <td id="T_11a42_row3_col3" class="data row3 col3" >0.1</td>
#       <td id="T_11a42_row3_col4" class="data row3 col4" >4.8</td>
#       <td id="T_11a42_row3_col5" class="data row3 col5" >10.2</td>
#       <td id="T_11a42_row3_col6" class="data row3 col6" >7.1</td>
#       <td id="T_11a42_row3_col7" class="data row3 col7" >2.5</td>
#     </tr>
#     <tr>
#       <th id="T_11a42_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_11a42_row4_col0" class="data row4 col0" >Has appealing benefits or rewards</td>
#       <td id="T_11a42_row4_col1" class="data row4 col1" >20.8</td>
#       <td id="T_11a42_row4_col2" class="data row4 col2" >4.0</td>
#       <td id="T_11a42_row4_col3" class="data row4 col3" >0.2</td>
#       <td id="T_11a42_row4_col4" class="data row4 col4" >7.4</td>
#       <td id="T_11a42_row4_col5" class="data row4 col5" >8.4</td>
#       <td id="T_11a42_row4_col6" class="data row4 col6" >6.6</td>
#       <td id="T_11a42_row4_col7" class="data row4 col7" >3.9</td>
#     </tr>
#     <tr>
#       <th id="T_11a42_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_11a42_row5_col0" class="data row5 col0" >Rewards me for responsi

# %%
styled_df = results.style.background_gradient(cmap='Greens', axis=None, vmin=0, vmax=29.0)

styled_df
# Out:
# <style type="text/css">
# #T_997aa_row0_col1, #T_997aa_row8_col1 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_997aa_row0_col2 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_997aa_row0_col3 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_997aa_row0_col4 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_997aa_row0_col5 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_997aa_row0_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_997aa_row0_col7 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_997aa_row1_col1 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_997aa_row1_col2, #T_997aa_row1_col7 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_997aa_row1_col3, #T_997aa_row3_col3, #T_997aa_row5_col3, #T_997aa_row6_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_997aa_row1_col4 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_997aa_row1_col5, #T_997aa_row3_col5 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_997aa_row1_col6 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_997aa_row2_col1, #T_997aa_row8_col6 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_997aa_row2_col2 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_997aa_row2_col3, #T_997aa_row4_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_997aa_row2_col4 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_997aa_row2_col5 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_997aa_row2_col6 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_997aa_row2_col7 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_997aa_row3_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_997aa_row3_col2, #T_997aa_row3_col7 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_997aa_row3_col4 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_997aa_row3_col6 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_997aa_row4_col1 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_997aa_row4_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_997aa_row4_col4 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_997aa_row4_col5 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_997aa_row4_col6 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_997aa_row4_col7 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_997aa_row5_col1 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_997aa_row5_col2, #T_997aa_row5_col7 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_997aa_row5_col4 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_997aa_row5_col5 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_997aa_row5_col6 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_997aa_row6_col1 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_997aa_row6_col2, #T_997aa_row6_col7 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_997aa_row6_col4 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_997aa_row6_col5 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_997aa_row6_col6 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_997aa_row7_col1 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_997aa_row7_col2, #T_997aa_row7_col7 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_997aa_row7_col3 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_997aa_row7_col4 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_997aa_row7_col5 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_997aa_row7_col6 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_997aa_row8_col2 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_997aa_row8_col3 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_997aa_row8_col4 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_997aa_row8_col5 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_997aa_row8_col7 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_997aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_997aa_level0_col0" class="col_heading level0 col0" >Perception</th>
#       <th id="T_997aa_level0_col1" class="col_heading level0 col1" >Pearson Correlations (%)</th>
#       <th id="T_997aa_level0_col2" class="col_heading level0 col2" >Standardized Multiple Regression Coefficients (%)</th>
#       <th id="T_997aa_level0_col3" class="col_heading level0 col3" >Shapley Values (%)</th>
#       <th id="T_997aa_level0_col4" class="col_heading level0 col4" >Johnson's Epsilon (%)</th>
#       <th id="T_997aa_level0_col5" class="col_heading level0 col5" >Mean Decrease in RF Gini Coefficient (%)</th>
#       <th id="T_997aa_level0_col6" class="col_heading level0 col6" >XGBoost Importance (%)</th>
#       <th id="T_997aa_level0_col7" class="col_heading level0 col7" >Usefulness (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_997aa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_997aa_row0_col0" class="data row0 col0" >Is offered by a brand I trust</td>
#       <td id="T_997aa_row0_col1" class="data row0 col1" >25.600000</td>
#       <td id="T_997aa_row0_col2" class="data row0 col2" >13.600000</td>
#       <td id="T_997aa_row0_col3" class="data row0 col3" >2.700000</td>
#       <td id="T_997aa_row0_col4" class="data row0 col4" >25.300000</td>
#       <td id="T_997aa_row0_col5" class="data row0 col5" >14.900000</td>
#       <td id="T_997aa_row0_col6" class="data row0 col6" >29.000000</td>
#       <td id="T_997aa_row0_col7" class="data row0 col7" >13.800000</td>
#     </tr>
#     <tr>
#       <th id="T_997aa_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_997aa_row1_col0" class="data row1 col0" >Helps build credit quickly</td>
#       <td id="T_997aa_row1_col1" class="data row1 col1" >19.200000</td>
#       <td id="T_997aa_row1_col2" class="data row1 col2" >2.300000</td>
#       <td id="T_997aa_row1_col3" class="data row1 col3" >0.100000</td>
#       <td id="T_997aa_row1_col4" class="data row1 col4" >4.400000</td>
#       <td id="T_997aa_row1_col5" class="data row1 col5" >10.100000</td>
#       <td id="T_997aa_row1_col6" class="data row1 col6" >7.900000</td>
#       <td id="T_997aa_row1_col7" class="data row1 col7" >2.300000</td>
#     </tr>
#     <tr>
#       <th id="T_997aa_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_997aa_row2_col0" class="data row2 col0" >Is different from other cards</td>
#       <td id="T_997aa_row2_col1" class="data row2 col1" >18.500000</td>
#       <td id="T_997aa_row2_col2" class="data row2 col2" >3.300000</td>
#       <td id="T_997aa_row2_col3" class="data row2 col3" >0.200000</td>
#       <td id="T_997aa_row2_col4" class="data row2 col4" >6.100000</td>
#       <td id="T_997aa_row2_col5" class="data row2 col5" >9.400000</td>
#       <td id="T_997aa_row2_col6" class="data row2 col6" >5.600000</td>
#       <td id="T_997aa_row2_col7" class="data row2 col7" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_997aa_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_997aa_row3_col0" class="data row3 col0" >Is easy to use</td>
#       <td id="T_997aa_row3_col1" class="data row3 col1" >21.300000</td>
#       <td id="T_997aa_row3_col2" class="data row3 col2" >2.600000</td>
#       <td id="T_997aa_row3_col3" class="data row3 col3" >0.100000</td>
#       <td id="T_997aa_row3_col4" class="data row3 col4" >4.800000</td>
#       <td id="T_997aa_row3_col5" class="data row3 col5" >10.100000</td>
#       <td id="T_997aa_row3_col6" class="data row3 col6" >7.100000</td>
#       <td id="T_997aa_row3_col7" class="data row3 col7" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_997aa_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_997aa_row4_col0" class="data row4 col0" >Has appealing benefits or rewards</td>
#       <td id="T_997aa_row4_col1" class="data row4 col1" >20.800000</td>
#       <td id="T_997aa_row4_col2" class="data row4 col2" >4.000000</td>
#       <td id="T_997aa_row4_col3" class="data row4 col3" >0.200000</td>
#       <td id="T_997aa_row4_col4" class="data row4 col4" >7.400000</td>
#       <td id="T_997aa_row4_col5" class="data row4 col5" >8.400
